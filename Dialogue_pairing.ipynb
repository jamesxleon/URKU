# %% [markdown]
# # Parsing the file content to a dictionary
#
# From the elan converted texts
#
# ```
# defaultdict(<function __main__.parse_file_content.<locals>.<lambda>()>,
#             {'Simeon': defaultdict(list,
#                          {'po': ['Sentence 1 in po', 'Sentence 2 in po'],
#                           'tn': ['Sentence 1 in tn', 'Sentence 2 in tn']})})
#
# ```

# %%
from collections import defaultdict
import re

def parse_file_content(file_content):
    # Initialize data structure to hold parsed content
    parsed_data = defaultdict(lambda: defaultdict(list))
    
    # Split the content by lines and initialize variables
    lines = file_content.strip().split("\n")
    current_speaker = None
    current_tier = None
    
    # Regular expression patterns for extracting information
    speaker_pattern = r"Speaker: (.+)"
    tier_pattern = r"Tier Type: (\w+), Annotations Count: \d+"
    annotation_pattern = r"Annotation: (.+)"
    
    # Parse the lines one by one
    for line in lines:
        speaker_match = re.search(speaker_pattern, line)
        if speaker_match:
            current_speaker = speaker_match.group(1)
            continue
        tier_match = re.search(tier_pattern, line)
        if tier_match:
            current_tier = tier_match.group(1)
            continue
        annotation_match = re.search(annotation_pattern, line)
        if annotation_match and current_speaker and current_tier:
            annotation = annotation_match.group(1)
            if annotation.lower() != "none":  # Skip "None" annotations
                parsed_data[current_speaker][current_tier].append(annotation)
            
    return parsed_data

# %% [markdown]
# # Join annotations from the parsed data

# %%
def join_annotations_by_index(parsed_data):
    joined_data = defaultdict(list)
    
    for speaker, tiers in parsed_data.items():
        # Get the number of annotations in the 'po' tier for comparison
        po_count = len(tiers.get('po', []))
        tn_count = len(tiers.get('tn', []))

        print(f"Speaker: {speaker}, po: {po_count}, tn: {tn_count}")

        # Skip the speaker if 'po' annotations are empty
        if po_count == 0:
            continue

        # Initialize a list to hold the joined annotations for this speaker
        joined_annotations = [{} for _ in range(po_count)]
        
        # First, handle the special case for 'po' and 'tn'
        # They should be identical, so we can just copy them directly
        for i in range(po_count):
            joined_annotations[i]['po'] = tiers.get('po', [None])[i]
            joined_annotations[i]['tn'] = tiers.get('tn', [None])[min(i, tn_count - 1)] if tn_count > 0 else "none"
        
        # Loop through each tier type and its annotations, excluding 'po' and 'tn'
        for tier, annotations in {k: v for k, v in tiers.items() if k not in ['po', 'tn']}.items():
            # If the annotation counts match 'po', join by index
            if len(annotations) == po_count:
                for i, annotation in enumerate(annotations):
                    joined_annotations[i][tier] = annotation
            else:
                # If counts don't match, mark it for later processing
                for i, annotation in enumerate(annotations):
                    if 'unmatched' not in joined_annotations[min(i, po_count-1)]:
                        joined_annotations[min(i, po_count-1)]['unmatched'] = {}
                    joined_annotations[min(i, po_count-1)]['unmatched'][tier] = annotation
                    
        # Store the joined annotations for this speaker
        joined_data[speaker] = joined_annotations

    return joined_data

# %% [markdown]
# ## Join annotations in case they don't match by indexing using levenshtein distance

# %%
def levenshtein_distance(s1, s2):
    """
    Calculate the Levenshtein distance between two strings.
    """
    if len(s1) < len(s2):
        return levenshtein_distance(s2, s1)

    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]

# %%
from itertools import chain

def match_unmatched_annotations(joined_data):
    # Initialize data structure to hold the final matched annotations
    matched_data = defaultdict(list)
    
    for speaker, annotations in joined_data.items():
        # Initialize a list to hold the matched annotations for this speaker
        matched_annotations = []
        
        for annotation_set in annotations:
            # Initialize a dictionary to hold the matched annotation for this set
            matched_annotation = {}
            
            # Copy over the annotations that were already matched by index
            for tier, annotation in chain(annotation_set.items(), annotation_set.get('unmatched', {}).items()):
                if tier != 'unmatched':
                    matched_annotation[tier] = annotation
            
            # Handle unmatched annotations, if any
            unmatched_tiers = annotation_set.get('unmatched', {})
            if unmatched_tiers:
                po_annotation = annotation_set['po']
                for tier, annotation in unmatched_tiers.items():
                    # Calculate the Levenshtein distance to the 'po' annotation
                    distance = levenshtein_distance(po_annotation, annotation)
                    
                    # If the distance is below a certain threshold, match it
                    # Here we use a threshold of 5 as an example; you can adjust this as needed
                    if distance < 5:
                        matched_annotation[tier] = annotation
                    else:
                        matched_annotation[tier] = "none"  # No good match found
                        
            # Add the matched annotation set to the list for this speaker
            matched_annotations.append(matched_annotation)
        
        # Store the matched annotations for this speaker
        matched_data[speaker] = matched_annotations

    return matched_data

# %% [markdown]
# # Join everything together

# %%
import os
import json

def process_and_save_annotations(input_dir, output_dir):
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Loop through each file in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            filepath = os.path.join(input_dir, filename)
            
            # Step 2: Read the content of the file
            with open(filepath, 'r', encoding='utf-8') as f:
                print(f"Current file: {filename}\n")
                file_content = f.read()
            
            # Step 3: Parse the content
            parsed_data = parse_file_content(file_content)
            
            # Step 4: Join annotations by index
            joined_data = join_annotations_by_index(parsed_data)
            
            # Step 5: Match unmatched annotations
            matched_data = match_unmatched_annotations(joined_data)
            
            # Step 6: Save the final matched annotations to a file in the output directory
            output_filepath = os.path.join(output_dir, f"{filename.split('.')[0]}_processed.json")
            with open(output_filepath, 'w', encoding='utf-8') as f:
                json.dump(matched_data, f, ensure_ascii=False, indent=4)
            
            print("\n\n")

# %%
# Let's test the function with the uploaded file and save the output to a test directory
input_dir = 'Data/Simeon/Floyd_merged/'
output_dir = 'Data/Simeon/TestResults/'
process_and_save_annotations(input_dir, output_dir)

# Check if the output file has been generated
os.listdir(output_dir)
# Out:
# Current file: QUSF2018_02_09S1_pub.txt
#
# Speaker: señora de saco azul, po: 81, tn: 81
# Speaker: señora de chalinaa, po: 38, tn: 38
# Speaker: señora de saco blanco, po: 111, tn: 111
# Speaker: Simeon, po: 115, tn: 115
# Speaker: señora con sombrero, po: 27, tn: 27
#
#
#
# Current file: QUSF2018_10_09S1_pub.txt
#
# Speaker: HOMBRE 1 A, po: 987, tn: 987
# Speaker: HOMBRE 2 B, po: 1466, tn: 1466
# Speaker: MUJER 1 C, po: 16, tn: 0
# Speaker: MUJERV 1 C, po: 0, tn: 16
# Speaker: Simeon D, po: 33, tn: 33
#
#
#
# Current file: QUSF2018_02_24S2_pub.txt
#
# Speaker: SIMEON A, po: 720, tn: 0
# Speaker: SIMEON  A, po: 0, tn: 720
# Speaker: mujer 1 B, po: 1166, tn: 1166
# Speaker: hombre 1 C, po: 798, tn: 797
# Speaker: D, po: 80, tn: 80
#
#
#
# Current file: QUSF2019_03_03S1_pub.txt
#
# Speaker: Entrevistador, po: 94, tn: 94
# Speaker: Mujer joven, po: 107, tn: 107
# Speaker: Abuelita, po: 64, tn: 64
# Speaker: Simeon, po: 32, tn: 32
#
#
#
# Current file: QUSF2018_08_25S2_pub.txt
#
# Speaker: Hombre, po: 245, tn: 244
# Speaker: Niño, po: 3, tn: 3
# Speaker: Mujer  chalina blanca, po: 25, tn: 0
# Speaker: C, po: 0, tn: 0
# Speaker: Mujer Chalina blanco, po: 0, tn: 25
# Speaker: Simeon, po: 85, tn: 85
# Speaker: Mujer chalina azul, po: 73, tn: 73
# Speaker: Hombre de chompa cafe, po: 102, tn: 102
#
#
#
# Current file: QUSF2018_09_16S2_pub.txt
#
# Speaker: mujer 1.1, po: 293, tn: 293
# Speaker: hombre 1, po: 196, tn: 0
# Speaker: B, po: 0, tn: 0
# Speaker: hombre 1_, po: 0, tn: 196
# Speaker: mujer, po: 103, tn: 103
# Speaker: simeon, po: 56, tn: 56
#
#
#
# Current file: QUSF2018_09_02S2_pub.txt
#
# Speaker: hombre, po: 180, tn: 180
# Speaker: Mujer, po: 88, tn: 87
# Speaker: señora2, po: 13, tn: 13
# Speaker: Niño, po: 2, tn: 2
#
#
#
# Current file: QUSF2019_03_22S1_pub.txt
#
# Speaker: Simeón, po: 680, tn: 0
# Speaker: Simeón A, po: 0, tn: 680
# Speaker: María Tutillo, po: 1184, tn: 1183
# Speaker: mujer 2, po: 4, tn: 0
# Speaker: mujer 2 C, po: 0, tn: 4
#
#
#
# Current file: QUSF2018_02_03S2_pub.txt
#
# Speaker: A, po: 705, tn: 701
# Speaker: B, po: 394, tn: 394
#
#
#
# Current file: QUSF2020_01_04S1_pub.txt
#
# Speaker: simeon, po: 1001, tn: 1000
# Speaker: hombre 1, po: 838, tn: 838
# Speaker: C, po: 2, tn: 2
#
#
#
# Current file: QUSF2019_12_19S1_pub.txt
#
# Speaker: Simeon, po: 1039, tn: 1038
# Speaker: Hombre 1, po: 1916, tn: 1916
#
#
#
# Current file: QUSF2019_03_23S2_pub.txt
#
# Speaker: hombre 1, po: 762, tn: 757
# Speaker: simeon 1, po: 109, tn: 109
# Speaker: mujer 1, po: 15, tn: 15
# Speaker: hombre 2, po: 4, tn: 0
# Speaker: hombre 2 D, po: 0, tn: 4
# Speaker: mujer 2, po: 155, tn: 155
# Speaker: niño1, po: 4, tn: 0
# Speaker: niño 1, po: 0, tn: 4
#
#
#
# Current file: QUSF2018_09_09S1_pub.txt
#
# Speaker: Mujer Joven, po: 195, tn: 195
# Speaker: Mujer vieja, po: 252, tn: 0
# Speaker: B, po: 0, tn: 0
# Speaker: Mujer Vieja, po: 0, tn: 251
# Speaker: Niño, po: 9, tn: 7
# Speaker: Simeon, po: 253, tn: 253
# Speaker: Hombre 1, po: 16, tn: 11
# Speaker: Hombre 2, po: 23, tn: 23
#
#
#
# Current file: QUSF2018_02_24S1_pub.txt
#
# Speaker: Anciana saco amarillo, po: 246, tn: 243
# Speaker: Anciana saco azul, po: 277, tn: 275
# Speaker: Simeon, po: 129, tn: 129
# Speaker: Grabacion, po: 2, tn: 2
# Speaker: Anciana saco rosado, po: 59, tn: 59
# Speaker: Voz de telefono, po: 2, tn: 2
#
#
#
# Current file: QUSF2018_10_09S2_pub.txt
#
# Speaker: persona 1 simeon, po: 103, tn: 103
# Speaker: persona 2, po: 215, tn: 214
# Speaker: persona 3, po: 181, tn: 181
# Speaker: mujer, po: 164, tn: 164
# Speaker: E, po: 155, tn: 155
# Speaker: mujer 2, po: 164, tn: 164
# Speaker: F, po: 0, tn: 0
# Speaker: mujer  2, po: 0, tn: 1
#
#
#
# Current file: QUSF2019_03_04S1_pub.txt
#
# Speaker: Chica, po: 8, tn: 8
# Speaker: Mama, po: 266, tn: 266
# Speaker: Simeon, po: 39, tn: 39
#
#
#
# Current file: QUSF2018_10_10S2_pub.txt
#
# Speaker: Adulto mayor, po: 282, tn: 282
# Speaker: hombre 1, po: 289, tn: 0
# Speaker: B, po: 0, tn: 0
# Speaker: hombre 1_, po: 0, tn: 289
# Speaker: C, po: 49, tn: 49
#
#
#
# Current file: QUSF2018_03_11S1_pub.txt
#
# Speaker: Delia, po: 139, tn: 139
# Speaker: Lucia, po: 196, tn: 195
# Speaker: Simeon, po: 174, tn: 173
# Speaker: Niña, po: 7, tn: 7
# Speaker: Niño, po: 22, tn: 22
# Speaker: Mujer3, po: 57, tn: 55
# Speaker: Hombre2, po: 15, tn: 15
#
#
#
# Current file: QUSF2020_01_04S2_pub.txt
#
# Speaker: Simeon, po: 2412, tn: 2408
# Speaker: hombre 1, po: 1619, tn: 1617
# Speaker: mujer 1, po: 12, tn: 12
#
#
#
# Current file: QUSF2018_09_02S1_pub.txt
#
# Speaker: mujer 2, po: 211, tn: 211
# Speaker: simon, po: 21, tn: 21
# Speaker: mujer 1, po: 295, tn: 295
#
#
#
# Current file: QUSF2018_09_16S1_pub.txt
#
# Speaker: Paya Mama, po: 70, tn: 70
# Speaker: Miguel, po: 139, tn: 139
# Speaker: Simeon, po: 61, tn: 61
# Speaker: Mujer, po: 8, tn: 8
# Speaker: Ruku Tayta, po: 231, tn: 231
# Speaker: Mujer 2, po: 12, tn: 12
#
#
#
# Current file: QUSF2018_04_21S1_pub.txt
#
# Speaker: hombre 1, po: 256, tn: 256
# Speaker: mujer 1, po: 240, tn: 240
# Speaker: simeon, po: 159, tn: 159
# Speaker: D, po: 3, tn: 3
# Speaker: E, po: 3, tn: 0
#
#
#
# Current file: QUSF2018_12_23S2_pub.txt
#
# Speaker: Hombre1, po: 109, tn: 109
# Speaker: Mujer1, po: 19, tn: 19
# Speaker: Simeon, po: 70, tn: 70
# Speaker: Hombre2, po: 23, tn: 23
# Speaker: Mujer2, po: 3, tn: 3
# Speaker: Hombre 3, po: 1, tn: 1
#
#
#
# Current file: QUSF2018_02_18S2_pub.txt
#
# Speaker: Sr. Dirige, po: 363, tn: 363
# Speaker: Andres Anrango, po: 62, tn: 62
# Speaker: Poncho Rojo, po: 38, tn: 38
# Speaker: Hortencia, po: 25, tn: 25
# Speaker: Rebeca, po: 34, tn: 34
# Speaker: Simeon Floyd, po: 71, tn: 71
# Speaker: Ponch rojo 2, po: 131, tn: 0
# Speaker: H, po: 0, tn: 0
# Speaker: Poncho rojo 2, po: 0, tn: 129
# Speaker: Nicolas Muzo, po: 102, tn: 89
#
#
#
# Current file: QUSF2018_10_14S1_pub.txt
#
# Speaker: Simeon, po: 304, tn: 0
# Speaker: Simeòn A, po: 0, tn: 304
# Speaker: hombre 1 B, po: 269, tn: 269
# Speaker: mujer 1 C, po: 783, tn: 781
# Speaker: mujer 2, po: 371, tn: 0
# Speaker: mujer 2 D, po: 0, tn: 369
# Speaker: hombre 2, po: 462, tn: 0
# Speaker: hombre 2 E, po: 0, tn: 461
# Speaker: F, po: 2, tn: 1
#
#
#
# Current file: QUSF2018_06_22S1_pub.txt
#
# Speaker: Mujer 1, po: 560, tn: 0
# Speaker: Mujer 1 A, po: 0, tn: 560
# Speaker: Mujer 2 B, po: 307, tn: 307
# Speaker: niño 1 C, po: 15, tn: 15
# Speaker: hombre 1 D, po: 31, tn: 31
# Speaker: mujer 3 E, po: 70, tn: 70
# Speaker: Simeón, po: 388, tn: 0
# Speaker: Simeón F, po: 0, tn: 386
# Speaker: niña 1 G, po: 4, tn: 4
#
#
#
# Current file: QUSF2019_01_09S1_pub.txt
#
# Speaker: simeon, po: 143, tn: 143
# Speaker: mujer 1 de rosa, po: 161, tn: 161
# Speaker: mujer 2, po: 43, tn: 43
#
#
#
# Current file: QUSF2018_12_02S1_pub.txt
#
# Speaker: hombre1, po: 257, tn: 0
# Speaker: simeon, po: 372, tn: 371
# Speaker: mujer 1, po: 203, tn: 202
# Speaker: D, po: 7, tn: 7
#
#
#
# Current file: QUSF2018_12_23S1_pub.txt
#
# Speaker: Simeon, po: 79, tn: 79
# Speaker: Mario, po: 194, tn: 194
# Speaker: Pocho rojo 1, po: 77, tn: 0
# Speaker: C, po: 0, tn: 0
# Speaker: Poncho rojo 1, po: 0, tn: 77
# Speaker: D, po: 0, tn: 0
# Speaker: Sr. Gorra Amarilla, po: 0, tn: 96
# Speaker: Poncho rojo 2, po: 52, tn: 52
# Speaker: camisa blanca, po: 3, tn: 0
# Speaker: F, po: 0, tn: 0
# Speaker: Camisa Blanca, po: 0, tn: 3
# Speaker: Mujer, po: 3, tn: 3
#
#
#
# Current file: QUSF2019_12_17S1_pub.txt
#
# Speaker: Simeon, po: 1350, tn: 1349
# Speaker: Segundo Cumbal, po: 1325, tn: 1325
# Speaker: mujer 1, po: 19, tn: 19
#
#
#
# Current file: QUSF2018_02_03S1 _pub.txt
#
# Speaker: Simeon, po: 205, tn: 205
# Speaker: Rosario Tupiza, po: 246, tn: 246
# Speaker: Hermelinda Tituaña, po: 53, tn: 53
#
#
#
# Current file: QUSF2019_01_09S2_pub.txt
#
# Speaker: simeon, po: 369, tn: 0
# Speaker: A, po: 0, tn: 0
# Speaker: simeon _, po: 0, tn: 369
# Speaker: mujer 1, po: 482, tn: 480
# Speaker: C, po: 49, tn: 49
#
#
#
# Current file: QUSF2018_10_10S4_pub.txt
#
# Speaker: señor con gorra, po: 105, tn: 103
# Speaker: señor con sombrero, po: 256, tn: 252
#
#
#
# Current file: QUSF2018_06_22S2_pub.txt
#
# Speaker: Mujer con gorra, po: 213, tn: 212
# Speaker: Mujer camiseta blanca, po: 117, tn: 116
# Speaker: Hombre gorra, po: 6, tn: 6
# Speaker: Simeon, po: 83, tn: 83
# ['QUSF2018_10_14S1_pub_processed.json',
#  'QUSF2018_09_16S2_pub_processed.json',
#  'QUSF2018_10_10S4_pub_processed.json',
#  'QUSF2018_03_11S1_pub_processed.json',
#  'QUSF2019_12_19S1_pub_processed.json',
#  'QUSF2018_10_09S2_pub_processed.json',
#  'QUSF2020_01_04S2_pub_processed.json',
#  'QUSF2018_02_24S1_pub_processed.json',
#  'QUSF2020_01_04S1_pub_processed.json',
#  'QUSF2018_02_24S2_pub_processed.json',
#  '.DS_Store',
#  'QUSF2018_10_09S1_pub_processed.json',
#  'QUSF2018_09_16S1_pub_processed.json',
#  'QUSF2019_03_22S1_pub_processed.json',
#  'QUSF2019_03_03S1_pub_processed.json',
#  'QUSF2019_12_17S1_pub_processed.json',
#  'QUSF2019_03_23S2_pub_processed.json',
#  'QUSF2018_10_10S2_pub_processed.json',
#  'QUSF2018_02_18S2_pub_processed.json',
#  'QUSF2018_02_09S1_pub_processed.json',
#  'QUSF2019_01_09S1_pub_processed.json',
#  'QUSF2018_02_03S1 _pub_processed.json',
#  'QUSF2018_09_09S1_pub_processed.json',
#  'QUSF2019_01_09S2_pub_processed.json',
#  'QUSF2018_02_03S2_pub_processed.json',
#  'QUSF2018_12_02S1_pub_processed.json',
#  'QUSF2018_06_22S1_pub_processed.json',
#  'QUSF2018_12_23S1_pub_processed.json',
#  'QUSF2018_09_02S2_pub_processed.json',
#  'QUSF2018_09_02S1_pub_processed.json',
#  'QUSF2018_08_25S2_pub_processed.json',
#  'QUSF2019_03_04S1_pub_processed.json',
#  'QUSF2018_12_23S2_pub_processed.json',
#  'QUSF2018_04_21S1_pub_processed.json',
#  'QUSF2018_06_22S2_pub_processed.json']
